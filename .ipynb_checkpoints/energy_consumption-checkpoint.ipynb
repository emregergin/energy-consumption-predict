# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split 
# %matplotlib inline

# %%
df_train = pd.read_csv("./train_energy_data.csv")
df_test = pd.read_csv("./test_energy_data.csv")
df_train.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Building Type        1000 non-null   object
#  1   Square Footage       1000 non-null   int64
#  2   Number of Occupants  1000 non-null   int64
#  3   Appliances Used      1000 non-null   int64
#  4   Average Temperature  1000 non-null   float64
#  5   Day of Week          1000 non-null   object
#  6   Energy Consumption   1000 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %%
sns.histplot(df_train["Energy Consumption"],kde=True)
plt.show()

# %%
sns.scatterplot(x=df_train["Square Footage"],y=df_train["Energy Consumption"])
plt.show()

sns.heatmap(data=df_train.corr(numeric_only=True),annot=True)
plt.show()

# %%
sns.boxplot(x='Building Type', y='Energy Consumption', data=df_train)
plt.title('Bina Tipi ve Enerji Tüketimi')
plt.show()

sns.boxplot(x='Day of Week', y='Energy Consumption', data=df_train)
plt.title('Haftanın Günü ve Enerji Tüketimi')
plt.show()

# %%
df = pd.concat([df_train,df_test],ignore_index=True)

# %%
df.tail()
# Out:
#      Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 1095    Commercial            1161                   81               11
# 1096   Residential           37943                   50               23
# 1097    Commercial            1558                   27               29
# 1098    Industrial            2145                   56               12
# 1099   Residential           42414                   72               24
#
#       Average Temperature Day of Week  Energy Consumption
# 1095                15.45     Weekend             3010.81
# 1096                21.73     Weekend             4248.49
# 1097                16.86     Weekend             2843.60
# 1098                11.77     Weekend             3348.39
# 1099                29.62     Weekday             4722.59

# %%
df["Building Type"].unique()
# Out:
# array(['Residential', 'Commercial', 'Industrial'], dtype=object)

# %%
df = pd.get_dummies(df, columns=["Building Type", "Day of Week"], drop_first=True)
df
# Out:
#       Square Footage  Number of Occupants  Appliances Used  \
# 0               7063                   76               10
# 1              44372                   66               45
# 2              19255                   37               17
# 3              13265                   14               41
# 4              13375                   26               18
# ...              ...                  ...              ...
# 1095            1161                   81               11
# 1096           37943                   50               23
# 1097            1558                   27               29
# 1098            2145                   56               12
# 1099           42414                   72               24
#
#       Average Temperature  Energy Consumption  Building Type_Industrial  \
# 0                   29.84             2713.95                     False
# 1                   16.72             5744.99                     False
# 2                   14.30             4101.24                      True
# 3                   32.82             3009.14                     False
# 4                   11.92             3279.17                     False
# ...                   ...                 ...                       ...
# 1095                15.45             3010.81                     False
# 1096                21.73             4248.49                     False
# 1097                16.86             2843.60                     False
# 1098                11.77             3348.39                      True
# 1099                29.62             4722.59                     False
#
#       Building Type_Residential  Day of Week_Weekend
# 0                          True                False
# 1                         False                False
# 2                         False                 True
# 3                          True                False
# 4                         False                False
# ...                         ...                  ...
# 1095                      False                 True
# 1096                       True                 True
# 1097                      False                 True
# 1098                      False                 True
# 1099                       True                False
#
# [1100 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = tra
